# %% [markdown]
# <a href="https://colab.research.google.com/github/Varshinie13/Python-Learning-CaseStudies/blob/main/Beginner_to_advance_level_practice_sheet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Basic to advanced level Questions

# %%
print("Hello World")
# Out:
# Hello World

# %%
#	Check if a number is even or odd

num = int(input("Enter the number: "))
if num%2 == 0:
  print("The number is even")
else:
  print("The number is Odd")
# Out:
# Enter the number: 25
# The number is Odd

# %%
# Find largest of 3 numbers

num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))
num3 = int(input("Enter the third number: "))

if num1 > num2 and num1 > num3:
    print(num1, "is the largest number")
else:
    if num2 > num3:
        print(num2, "is the largest number")
    else:
        print(num3, "is the largest number")
# Out:
# Enter the first number: 34
# Enter the second number: 54
# Enter the third number: 2
# 54 is the largest number

# %%
#	Reverse a string

str = input("Enter the string:")
str= str[::-1]
print(str)
# Out:
# Enter the string:hi varshinie
# einihsrav ih

# %%
#Check palindrome string

string = input("Enter the string: ")
if string == string[::-1]:
  print("The string is palindrome")
else:
  print("The string is not a Palindrome")
# Out:
# Enter the string: madam
# The string is palindrome

# %%
#Find sum of digits of a number

Num = int(input("Enter the number: "))
Num1 = int(input("Enter the number: "))
Total = Num + Num1
print("Total is:", Total)
# Out:
# Enter the number: 30
# Enter the number: 20
# Total is: 50

# %% [markdown]
# String Based Questions
