# %% [markdown]
# <a href="https://colab.research.google.com/github/Varshinie13/Python-Practice-Sheet/blob/main/Python_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Day 1 Python Basics

# %% [markdown]
# Case Study – Student Registration System

# %%
Student_Name = input("Enter the Student Name : ")
Student_age = int(input("Enter Student Age : "))
Course_Name = input('Enter the Course Name :' )
Course_Fee = float(input('Enter the Fee : '))
# Out:
# Enter the Student Name : Vijaya
# Enter Student Age : 34
# Enter the Course Name :C++
# Enter the Fee : 40000

# %%
Gst = Course_Fee * 0.18
Total_Fee = Gst+Course_Fee

# %%
print("----- Student Details -----")


print(f"Student Name : {Student_Name}")
print(f"Student Age  : {Student_age}")
print(f"Course Name   : {Course_Name}")
# Out:
# ----- Student Details -----
# Student Name : Vijaya
# Student Age  : 34
# Course Name   : C++

# %%
print("---- Fee Details -----")

print(f"GST Amount   : {Gst}")
print(f"Total Fee    : {Total_Fee}")
# Out:
# ---- Fee Details -----
# GST Amount   : 7200.0
# Total Fee    : 47200.0

# %%
print(type(Student_Name))
print(type(Student_age))
print(type(Course_Name))
print(type(Total_Fee))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %% [markdown]
# Library Fine Calculator

# %%
Student_Name = input("Enter Student Name: ")
Book_Name = input("Enter Book Name: ")
Days_Late = int(input("Enter Number of Late Days: "))
Fine_per_day = float(input("Enter Fine Per Day: "))
# Out:
# Enter Student Name: Vijay
# Enter Book Name: Python Coding Book
# Enter Number of Late Days: 3
# Enter Fine Per Day: 20

# %%
Total_Fine = Days_Late * Fine_per_day

# %%
print("\n----- Library Fine Details -----")

print(f"Student Name   : {Student_Name}")
print(f"Book Name      : {Book_Name}")
print(f"Days Late      : {Days_Late}")
print(f"Fine Per Day   : {Fine_per_day}")
print(f"Total Fine     : {Total_Fine}")
# Out:
# ----- Library Fine Details -----
# Student Name   : Vijay
# Book Name      : Python Coding Book
# Days Late      : 3
# Fine Per Day   : 20.0
# Total Fine     : 60.0

# %%
print("\n----- Datatypes -----")

print(type(Student_Name))
print(type(Days_Late))
print(type(Fine_per_day))
# Out:
# ----- Datatypes -----
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %% [markdown]
# Case Study – Student ID Card Generator

# %%
Student_Name = input(("Enter the Student Name : "))
Roll_Number = input(("Enter the Roll_Number : "))
Department = input(("Enter the Department : "))
# Out:
# Enter the Student Name : Ajith
# Enter the Roll_Number : 2
# Enter the Department : Finance

# %%
Upper_Case = Student_Name.upper()
Upper_Case = Department.upper()

# %%
print(Student_Name[0:4])
print(Department[0:4])
# Out:
# Ajit
# Fina

# %%
Student_id = int(input('Enter the Student id : '))
# Out:
# Enter the Student id : 1

# %%
print(f"Student Name : {Student_Name}")
print(f"Roll_Number  : {Roll_Number}")
print(f"Department   : {Department}")
print(f"Student_id   : {Student_id}")
# Out:
# Student Name : Ajith
# Roll_Number  : 2
# Department   : Finance
# Student_id   : 1

# %% [markdown]
# Day 2 Challenge - Python Practice

# %%
a= 10
b= 30
c = 12.3

print(a,b,c)
# Out:
# 10 30 12.3

# %%
d= a+b+c
e = a/b
f = a*c
g = b-a
h = b%a
print ( ' ------- Arithematic Operations -------')
print (f'Addition : {d}')
print (f'Division : {e}')
print (f'Multiplication : {f}')
print (f'Subraction : {g}')
print (f'Modulus : {h}')
# Out:
#  ------- Arithematic Operations -------
# Addition : 52.3
# Division : 0.3333333333333333
# Multiplication : 123.0
# Subraction : 20
# Modulus : 0

# %%
print (type(a))
print (type(b))
print (type(c))
print (type(d))
print (type(e))
print (type(f))
print (type(g))
print (type(h))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'int'>
# <class 'int'>

# %%
a = 'The Warrior of Kingdom and the Queen'
len(a)
# Out:
# 36

# %%
reversed_a = a[::-1]
print(reversed_a)
# Out:
# neeuQ eht dna modgniK fo roirraW ehT

# %%
Letter = input('Enter the word : ')
if Letter in 'aeiou':
  print('The letter is vowel')
else:
  print('The letter is not Vowel')
# Out:
# Enter the word : s
# The letter is not Vowel

# %%
Word = input("Enter the Word: ")
if Word == Word[::-1]:
  print(f'{Word} is a Palindrome')
else:
    print(f'{Word} is not a Palindrome')
# Out:
# Enter the Word: Anitha
# Anitha is not a Palindrome
